# %% [markdown]
# # Linear regression from scratch
#
# Well, not really from scratch. But from https://www.coursera.org/learn/machine-learning/home/week/1
#
# Defining functions:
# - Loss function: squared errors between fitted line and target variable
# - Cost function to calculate the total average loss/error from target variable
# - Finding the best fit line: using gradient descent to minimize the cost function; adjusting parameters w, b with a fixed learning rate.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# create initial dataset

x = pd.Series([1, 3, 5, 10, 11, 12, 15, 16])
y = pd.Series([4, 5, 14, 18, 24, 27, 30, 40 ])

plt.scatter(x, y)
plt.title('To create a regression line for the below')
plt.show()

# %% [markdown]
# # Defining functions for simple linear regression model

# %%
# Linear model for making predictions of y based on x
# y = wx + b 
def model_fit(w, b, x):
    y = [ w*i + b for i in x ]
    return pd.Series(y)


# Loss function and cost function: calculate the squared errors/loss 
# (prediction - true values)^2 / (2 * number of values)
def mean_error(list_true, list_pred):
    return ((list_pred - list_true)**2).sum() / (2*len(list_true))
    

# calculate the gradient by taking the derivatives for w and b 
# The gradient of the cost function determines the direction and size 
# of the corrective step for new w and b values
def gradient_descent(w, b, learn_rate, list_true, list_pred):
    step_w = ((list_pred - list_true) * list_true).sum() / len(list_true)
    step_b = (list_pred - list_true).sum() / len(list_true)
    
    # calculate the new value of w and b, by deducting the learning step   
    tmp_b, tmp_w = None, None
    tmp_w = w - learn_rate * step_w
    tmp_b = b - learn_rate * step_b

    w = tmp_w if tmp_w else w    
    b = tmp_b if tmp_b else b
    return w, b



def train_model(w, b, learn_rate, x, y):

    count = 0
    fig, (ax1, ax2, ax3) = plt.subplots(3,1)
    ax1.set_title('Mean squared error vs Iterations')
    ax2.set_title("Mean squared error vs w")
    ax3.set_title("Mean squared error vs b")
    plt.tight_layout()
    
    # Conditions for stopping
    # if gradient = 0 or < 0.001
    # if number of iterations go above a certain value
    # if loss/mean square errors < 0.1 or a determined number
    # max of 500 iterations for gradient descent
    while count != 500:

        predictions = model_fit(w, b, x)
        error = mean_error(y, predictions)

        # plot graph of mean squared errors against number of iterations
        ax1.scatter(count, error )

        # plot graph of error against values of w and b
        ax2.scatter(w, error )
        ax3.scatter(b, error)
        
        if error < 3:
            break
        else:
            w, b = gradient_descent(w, b, learn_rate, y, predictions)
            count += 1
    
    print("w:", w, "\nb:", b, "\niterations:",count)
    return w, b 


def model_predict(w, b, x, y):
    new_y = w*x + b
#   return predictions of model
    return new_y    

def draw_model(w,b,x,y):
    new_y = model_predict(w,b,x,y)
    fig, ax = plt.subplots()
    ax.scatter(x, y)
    ax.plot(x, new_y)
    ax.set_title('Line of best fit')

# %%
x = pd.Series([1, 3, 5, 10, 11, 12, 15, 16])
y = pd.Series([4, 5, 14, 18, 24, 27, 30, 40 ])

# start_model(w, b, learn_rate, x, y)
# initial values for w, b, learn_rate
w, b = train_model(3, 1, 0.001, x, y)

# Draw best fit model line through the dataset
predictions = model_predict(w, b, x, y)
draw_model(w,b,x,y)
print("Predictions Mean error:", mean_error(y, predictions))
# Out:
# w: 2.179107265801093
# b: 0.759356946824835
# iterations: 500
# Predictions Mean error: 4.010172642717794

# %%
# start_model(w, b, learn_rate, x, y)
# initial values for w, b, learn_rate
w, b = train_model(3, 1, 0.0001, x, y)


# Draw best fit model line through the dataset
predictions = model_predict(w, b, x, y)
draw_model(w,b,x,y)
print("Predictions Mean error:", mean_error(y, predictions))

# With a smaller learning rate 0.0001 compared to 0.001, the curve is more gradual: 
# adjustment of w and b values are more gradual too.
# Out:
# w: 2.1635264213305505
# b: 0.9464743071924436
# iterations: 500
# Predictions Mean error: 4.033138682683625

# %% [markdown]
# # Depending on our initial values that we set for w and b, the linear model will return best line w and b values.
#
# In order to avoid getting stuck in a local minimum for the gradient descent (i.e. we want to find the global minimum), we can randomize initial values of w and b, and see which one results in the best line with minimum residuals.

# %%
# get randomized values for initial w and b
w = np.random.randint(-5,5,10)
b = np.random.randint(-5,5,10)

best_error = 10
best_wb = None

for i in range(len(w)):
    print("Using:", w[i], b[i])
    w_res, b_res = train_model(w[i],b[i],0.0003, x,y)
    predictions = model_predict(w_res, b_res, x, y)    
    error = mean_error(y, predictions)
    
    if error < best_error:
        best_error = error
        best_wb = (w_res, b_res)

    print("Model predictions mean error:", error)

print("-----"*10)    
print("Best wb:", best_wb)
print("Best error", best_error)
# Out:
# Using: -1 -3
# w: 2.475475254302646
# b: -2.79903462077409
# iterations: 500
# Model predictions mean error: 5.1991463994709335
# Using: 3 -2
# w: 2.4074072485589393
# b: -1.981764783750474
# iterations: 500
# Model predictions mean error: 4.652851997299615
# Using: -3 -1
# w: 2.3092804159442095
# b: -0.8035886403117721
# iterations: 500
# Model predictions mean error: 4.152039235648996
# Using: 2 -5
# w: 2.644675975348184
# b: -4.83057123187791
# iterations: 500
# Model predictions mean error: 7.2629382808911185
# Using: 1 1
# w: 2.1611208737083882
# b: 0.9753135563014906
# iterations: 500
# Model predictions mean error: 4.037423194910045
# Using: 0 -3
# w: 2.4784811369897484
# b: -2.835125251415597
# iterations: 500
# Model predictions mean error: 5.227026904502165
# Using: -4 -2
# w: 2.386366069749223
# b: -1.729130369259911
# iterations: 500
# Model predictions mean error: 4.516946498897078
# Using: -5 0
# w: 2.2231771140778886
# b: 0.23022498056089566
# iterations: 500
# Model predictions mean error: 3.9914865209228383
# Using: 2 -4
# w: 2.564584438856069
# b: -3.868938872288263
# iterations: 500
# Model predictions mean error: 6.160559217096025
# Using: -3 1
# w: 2.1490973429599776
# b: 1.1196760788675286
# iterations: 500
# Model predictions mean error: 4.061983541546114
# --------------------------------------------------
# Best wb: (2.2231771140778886, 0.23022498056089566)
# Best error 3.9914865209228383

# %%
print('w:', best_wb[0], 'b:', best_wb[1])
draw_model(best_wb[0], best_wb[1], x, y)
print(f'Best/lowest error: {best_error:.4f}')
print('Regression line formula')
print(f'y = {best_wb[0]:.2f}x + {best_wb[1]:.2f}')
# Out:
# w: 2.2231771140778886 b: 0.23022498056089566
# Best/lowest error: 3.9915
# Regression line formula
# y = 2.22x + 0.23

# %% [markdown]
# # End
